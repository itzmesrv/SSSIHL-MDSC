# %%
# importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.pyplot import figure
import scipy as scipy
from scipy import stats

# %%
# reading the dataset and printing it
df = pd.read_csv("E:/Siva/SSSIHL/MSc Data Science/1st Sem/102 Lab/wine/wine.data",names = attributes)

# giving names to all columns as attributes in the dataframe
attributes = ['Class','Alcohol','Malic Acid','Ash','Alcanlinity of ash','Magnesium','Total Phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color Intensity','Hue','OD280/OD315 of diluted wines','Proline']

# giving names to all columns as attributes in the dataframe
df.columns = attributes

# printing the dataframe
df
# Out:
#      Class  Alcohol  Malic Acid   Ash  Alcanlinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43                15.6        127
# 1        1    13.20        1.78  2.14                11.2        100
# 2        1    13.16        2.36  2.67                18.6        101
# 3        1    14.37        1.95  2.50                16.8        113
# 4        1    13.24        2.59  2.87                21.0        118
# ..     ...      ...         ...   ...                 ...        ...
# 173      3    13.71        5.65  2.45                20.5         95
# 174      3    13.40        3.91  2.48                23.0        102
# 175      3    13.27        4.28  2.26                20.0        120
# 176      3    13.17        2.59  2.37                20.0        120
# 177      3    14.13        4.10  2.74                24.5         96
#
#      Total Phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
# information about the data frame - data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic Acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcanlinity of ash            178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total Phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color Intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
# ...

# %%
# shape of the dataframe
df.shape
# Out:
# (178, 14)

# %%
# summary of dataframe - 6point summary
df.describe()
# Out:
#             Class     Alcohol  Malic Acid         Ash  Alcanlinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000          178.000000
# mean     1.938202   13.000618    2.336348    2.366517           19.494944
# std      0.775035    0.811827    1.117146    0.274344            3.339564
# min      1.000000   11.030000    0.740000    1.360000           10.600000
# 25%      1.000000   12.362500    1.602500    2.210000           17.200000
# 50%      2.000000   13.050000    1.865000    2.360000           19.500000
# 75%      3.000000   13.677500    3.082500    2.557500           21.500000
# max      3.000000   14.830000    5.800000    3.230000           30.000000
#
#         Magnesium  Total Phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
# Subplots for box plot and Histogram 
fig, axes = plt.subplots(1,2,figsize=(15,5)) # required rows,cols and plotsize
fig.subplots_adjust(hspace=0.3, wspace=0.3)

sns.boxplot(data=df,x='Magnesium',ax=axes[0],color='red')
sns.histplot(data=df,x='Magnesium',kde=True,ax=axes[1],color='green')

axes[0].set_title('Magnesium Box Plot')
axes[1].set_title('Magnesium Histogram with kde')
# Out:
# Text(0.5, 1.0, 'Magnesium Histogram with kde')

# %%
# to check the skewness of all the attributes in the dataframe
df.skew()
# Out:
# Class                           0.107431
# Alcohol                        -0.051482
# Malic Acid                      1.039651
# Ash                            -0.176699
# Alcanlinity of ash              0.213047
# Magnesium                       1.098191
# Total Phenols                   0.086639
# Flavanoids                      0.025344
# Nonflavanoid phenols            0.450151
# Proanthocyanins                 0.517137
# Color Intensity                 0.868585
# Hue                             0.021091
# OD280/OD315 of diluted wines   -0.307285
# Proline                         0.767822
# dtype: float64

# %%
# Histplot for OD280/OD315 of diluted wines
sns.histplot(data=df,x='OD280/OD315 of diluted wines',kde=True,color='green')
plt.title('Histplot for OD280/OD315 of diluted wines')
# Out:
# Text(0.5, 1.0, 'Histplot for OD280/OD315 of diluted wines')

# %%
# Histplot for Hue
sns.histplot(data=df,x='Hue',kde=True,color='green')
plt.title('Histplot for Hue')
# Out:
# Text(0.5, 1.0, 'Histplot for Hue')

# %%
# Subplots for box plot and Histogram for features: Magnesium, diluted wines, Hue
fig, axes = plt.subplots(3,2,figsize=(15,10)) # required rows,cols and plotsize
fig.subplots_adjust(hspace=0.5, wspace=0.3)

sns.boxplot(data=df,x='Magnesium',ax=axes[0,0],color='red')
sns.boxplot(data=df,x='OD280/OD315 of diluted wines',ax=axes[1,0],color='red')
sns.boxplot(data=df,x='Hue',ax=axes[2,0],color='red')
sns.histplot(data=df,x='Magnesium',kde=True,ax=axes[0,1],color='green')
sns.histplot(data=df,x='OD280/OD315 of diluted wines',kde=True,ax=axes[1,1],color='green')
sns.histplot(data=df,x='Hue',kde=True,ax=axes[2,1],color='green')

axes[0,0].set_title('Magnesium Box Plot')
axes[1,0].set_title('OD280/OD315 of diluted wines Box Plot')
axes[2,0].set_title('Hue Box Plot')
axes[0,1].set_title('Magensium Histplot')
axes[1,1].set_title('OD280/OD315 of diluted wines Histplot')
axes[2,1].set_title('Hue Histplot')

plt.savefig('name')

# %%
# Transformation of Magnesium into squareroot
sq_root = np.sqrt(df['Magnesium'])
sq_root.skew()
# Out:
# 0.8382312628407997

# %%
# Transformation of Magnesium into log
ln = np.log(df['Magnesium'])
ln.skew()
# Out:
# 0.6014446889284105

# %%
# Transformation of Magnesium into 1/x
by = 1 / df['Magnesium']
by.skew()
# Out:
# -0.17656461729558018

# %%
# Using boxcox and finding the lambda value
x = df['Magnesium']
arr, lam = scipy.stats.boxcox(x)
lam
# Out:
# -1.4291229687602396

# %%
# Applying boxcox transformation i.e. (x^lam - 1) / lam
boxcox = ( (df['Magnesium'] ** lam) - 1 ) / lam
boxcox.skew()
# Out:
# 0.0063529133891043485

# %%
# Plotting the histplot
sns.histplot(x=boxcox,kde=True,color='orange')
plt.title('Histplot for Magnesium which is transformed by boxcox')
# Out:
# Text(0.5, 1.0, 'Histplot for Magnesium which is transformed by boxcox')

# %%
# Subplots for qqplot - probability plot known as ppplot in scipy
fig, axes = plt.subplots(1,2,figsize=(15,5)) # required rows,cols and plotsize
fig.subplots_adjust(hspace=0.3, wspace=0.3)

stats.probplot(x,plot=axes[0])
stats.probplot(boxcox,plot=axes[1])

axes[0].set_title('Probability Plot for Magnesium')
axes[1].set_title('Probability Plot for transformed magnesium - Boxcox')
# Out:
# Text(0.5, 1.0, 'Probability Plot for transformed magnesium - Boxcox')
